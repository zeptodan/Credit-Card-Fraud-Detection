# %% [markdown]
# <a href="https://colab.research.google.com/github/zeptodan/Credit-Card-Fraud-Detection/blob/main/Credit_Card_Fraud_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.model_selection import RandomizedSearchCV
from imblearn.over_sampling import SMOTE
from sklearn.metrics import accuracy_score, roc_auc_score, f1_score, precision_score, recall_score

# %%
df = pd.read_csv("/content/drive/MyDrive/creditcard.csv")
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
X = df.drop("Class", axis=1)
Y = df["Class"]
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)

# %%
scalar = StandardScaler()
X_train = scalar.fit_transform(X_train)
X_test = scalar.transform(X_test)

# %%
def print_metrics(Y_test, Y_pred, Y_prob):
  score_f1 = f1_score(Y_test, Y_pred)
  score_roc = roc_auc_score(Y_test, Y_prob)
  score_acc = accuracy_score(Y_test, Y_pred)
  score_precision = precision_score(Y_test, Y_pred)
  score_recall = recall_score(Y_test, Y_pred)
  print(f"F1 Score: {score_f1}")
  print(f"Precision Score: {score_precision}")
  print(f"Recall Score: {score_recall}")
  print(f"ROC AUC Score: {score_roc}")
  print(f"Accuracy Score: {score_acc}")

# %%
model = LogisticRegression(max_iter=1000)
model.fit(X_train, Y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
Y_prob = model.predict_proba(X_test)[:,1]
Y_pred = (Y_prob > 0.1).astype(int)
print_metrics(Y_test, Y_pred, Y_prob)
# Out:
# F1 Score: 0.8350515463917526
# Precision Score: 0.84375
# Recall Score: 0.826530612244898
# ROC AUC Score: 0.9915828528935491
# Accuracy Score: 0.9994382219725431

# %%
random_forest = RandomForestClassifier(n_estimators=200,max_depth=10,min_samples_split=5)
random_forest.fit(X_train, Y_train)
# Out:
# RandomForestClassifier(max_depth=10, min_samples_split=5, n_estimators=200)

# %%
Y_prob = random_forest.predict_proba(X_test)[:,1]
Y_pred = (Y_prob > 0.3).astype(int)
print_metrics(Y_test, Y_pred, Y_prob)
# Out:
# F1 Score: 0.8367346938775511
# Precision Score: 0.8367346938775511
# Recall Score: 0.8367346938775511
# ROC AUC Score: 0.9836301149610097
# Accuracy Score: 0.9994382219725431

# %%
xgbc = XGBClassifier(eval_metric="logloss",verbosity=1)
params = {
    "n_estimators": [100, 200, 300],
    "max_depth": [3, 5, 7],
    "learning_rate": [0.01, 0.05, 0.1],
    "subsample": [0.8, 1.0],
    "colsample_bytree": [0.8, 1.0]
}
xgrandom = RandomizedSearchCV(
    estimator=xgbc,
    param_distributions=params,
    n_iter=10,
    scoring='f1',
    cv=5,
    random_state=42,
    n_jobs=1
)
xgrandom.fit(X_train, Y_train)
# Out:
# RandomizedSearchCV(cv=5,
#                    estimator=XGBClassifier(base_score=None, booster=None,
#                                            callbacks=None,
#                                            colsample_bylevel=None,
#                                            colsample_bynode=None,
#                                            colsample_bytree=None, device=None,
#                                            early_stopping_rounds=None,
#                                            enable_categorical=False,
#                                            eval_metric='logloss',
#                                            feature_types=None,
#                                            feature_weights=None, gamma=None,
#                                            grow_policy=None,
#                                            importance_type=None,
#                                            interaction_cons...
# ...

# %%
print("metrics on train set")
Y_prob = xgrandom.predict_proba(X_train)[:,1]
Y_pred = (Y_prob > 0.2).astype(int)
print_metrics(Y_train, Y_pred, Y_prob)
print("metrics on test set")
Y_prob = xgrandom.predict_proba(X_test)[:,1]
Y_pred = (Y_prob > 0.2).astype(int)
print_metrics(Y_test, Y_pred, Y_prob)
# Out:
# metrics on train set
# F1 Score: 0.9936788874841972
# Precision Score: 0.9899244332493703
# Recall Score: 0.9974619289340102
# ROC AUC Score: 0.9999996875547268
# Accuracy Score: 0.9999780552568632
# metrics on test set
# F1 Score: 0.8842105263157894
# Precision Score: 0.9130434782608695
# Recall Score: 0.8571428571428571
# ROC AUC Score: 0.9920643095448647
# Accuracy Score: 0.9996137776061234
